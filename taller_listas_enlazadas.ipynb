# %% [markdown]
# Punto 1)
#
# Ordenar una lista enlazada de numeros enteros positivos de menor a mayor

# %%
from random import randint

class Node:
    __slots__ = 'value', 'next'

    def __init__(self, value):
        self.value = value
        self.next = None

    def __str__(self):
        return str(self.value)


class LinkedList:

    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def __iter__(self):
        curr_node = self.head
        while curr_node is not None:
            yield curr_node
            curr_node = curr_node.next

    def __str__(self):
        result = [str(x.value) for x in self]
        return '--'.join(result)

    def append(self, value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = None
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1

    def prepend(self, value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node
        self.length += 1

    def get(self, index):
        if index == -1 or index == self.length - 1:
            return self.tail
        elif index < -1 or index >= self.length:
            return None

        indextemp = 0
        for cur_nodo in self:
            if indextemp == index:
                return cur_nodo
            indextemp += 1

    def insert(self, value, index):
        if index == 0:
            self.prepend(value)
            return True
        elif index == -1 or index == self.length - 1:
            self.append(value)
            return True
        elif index < -1 or index > self.length - 1:
            return False
        else:
            new_node = Node(value)
            prev_node = self.get(index - 1)
            new_node.next = prev_node.next
            prev_node.next = new_node
            self.length += 1
            return True
        return False

    def traverse(self):
        for x in self:
            print(x.value)

    def search(self, target):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"
        else:
            for cur_nodo in self:
                if cur_nodo.value == target:
                    return True

            return False

    def set(self, target, newtarget):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"
        else:
            for cur_nodo in self:
                if cur_nodo.value == target:
                    cur_nodo.value = newtarget
                    return True
            return False

    def pop_first(self):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"

        elif self.length == 1:
            popped_node = self.head
            self.head = None
            self.tail = None
            self.length = 0
            return popped_node
        else:
            popped_node = self.head
            self.head = self.head.next
            self.length -= 1
            popped_node.next = None
            return popped_node

    def pop(self):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"

        elif self.length == 1:
            popped_node = self.head
            self.head = None
            self.tail = None
            self.length = 0
            return popped_node
        else:
            popped_node = self.tail
            print("previo cola", self.get(self.length - 2))
            self.tail = self.get(self.length - 2)
            self.tail.next = None
            self.length -= 1
            return popped_node

    def remove(self, index):
        if index == 0:
            return self.pop_first()
        elif index == -1 or index == self.length - 1:
            return self.pop()
        elif index < -1 or index > self.length - 1:
            return False
        else:
            popped_node = self.get(index)
            prev_node = self.get(index - 1)
            prev_node.next = popped_node.next
            popped_node.next = None
            self.length -= 1
            return popped_node
        return False

    def delete(self):
        self.head = None
        self.tail = None
        self.length = 0

    def generate(self, n, minvalue, maxvalue):
        self.head = None
        self.tail = None
        self.length = 0
        for _ in range(n):
            self.append(randint(minvalue, maxvalue))
            
def sort_linked_list(head):    
    curr_node = head
    while curr_node:
        min_node = curr_node
        next_node = curr_node.next
        
        while next_node:
            if next_node.value < min_node.value:
                min_node = next_node
            next_node = next_node.next

        curr_node.value, min_node.value = min_node.value, curr_node.value
        curr_node = curr_node.next 
    return head


customll = LinkedList()
customll.generate(5, 1, 20)
print("Lista antes de ordenar:", customll)
sort_linked_list(customll.head)
print("Lista después de ordenar:", customll)

# Segunda prueba
customll2 = LinkedList()
customll2.append(9)
customll2.append(10)
customll2.append(11)
customll2.append(13)
customll2.append(8)

print("Lista 2 antes de ordenar: ", customll2)
sort_linked_list(customll2.head)
print("Lista 2 despues de ordenar", customll2)
# Out:
# Lista antes de ordenar: 4--2--19--19--11
# Lista después de ordenar: 2--4--11--19--19
# Lista 2 antes de ordenar:  9--10--11--13--8
# Lista 2 despues de ordenar 8--9--10--11--13

# %% [markdown]
# Segundo)
#
# Escriba una función que reciba una lista enlazada de numeros y devuelva los nodos numeros menores a un valor x a la
#
# izquierda y los nodos de un valor mayor a la derecha.

# %%
from random import randint


class Node:
    __slots__ = 'value', 'next'

    def __init__(self, value):
        self.value = value
        self.next = None

    def __str__(self):
        return str(self.value)


class LinkedList:

    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def __iter__(self):
        curr_node = self.head
        while curr_node is not None:
            yield curr_node
            curr_node = curr_node.next

    def __str__(self):
        result = [str(x.value) for x in self]
        return '--'.join(result)

    def append(self, value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = None
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1

    def prepend(self, value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node
        self.length += 1

    def get(self, index):
        if index == -1 or index == self.length - 1:
            return self.tail
        elif index < -1 or index >= self.length:
            return None

        indextemp = 0
        for cur_nodo in self:
            if indextemp == index:
                return cur_nodo
            indextemp += 1

    def insert(self, value, index):
        if index == 0:
            self.prepend(value)
            return True
        elif index == -1 or index == self.length - 1:
            self.append(value)
            return True
        elif index < -1 or index > self.length - 1:
            return False
        else:
            new_node = Node(value)
            prev_node = self.get(index - 1)
            new_node.next = prev_node.next
            prev_node.next = new_node
            self.length += 1
            return True
        return False

    def traverse(self):
        for x in self:
            print(x.value)

    def search(self, target):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"
        else:
            for cur_nodo in self:
                if cur_nodo.value == target:
                    return True

            return False

    def set(self, target, newtarget):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"
        else:
            for cur_nodo in self:
                if cur_nodo.value == target:
                    cur_nodo.value = newtarget
                    return True
            return False

    def pop_first(self):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"

        elif self.length == 1:
            popped_node = self.head
            self.head = None
            self.tail = None
            self.length = 0
            return popped_node
        else:
            popped_node = self.head
            self.head = self.head.next
            self.length -= 1
            popped_node.next = None
            return popped_node

    def pop(self):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"

        elif self.length == 1:
            popped_node = self.head
            self.head = None
            self.tail = None
            self.length = 0
            return popped_node
        else:
            popped_node = self.tail
            print("previo cola", self.get(self.length - 2))
            self.tail = self.get(self.length - 2)
            self.tail.next = None
            self.length -= 1
            return popped_node

    def remove(self, index):
        if index == 0:
            return self.pop_first()
        elif index == -1 or index == self.length - 1:
            return self.pop()
        elif index < -1 or index > self.length - 1:
            return False
        else:
            popped_node = self.get(index)
            prev_node = self.get(index - 1)
            prev_node.next = popped_node.next
            popped_node.next = None
            self.length -= 1
            return popped_node
        return False

    def delete(self):
        self.head = None
        self.tail = None
        self.length = 0

    def generate(self, n, minvalue, maxvalue):
        self.head = None
        self.tail = None
        self.length = 0
        for _ in range(n):
            self.append(randint(minvalue, maxvalue))
    
print("Proximo a terminar, no entendi muy bien que hacerle")
# Out:
# Proximo a terminar, no entendi muy bien que hacerle

# %% [markdown]
# Tercer punto)
#
# Escriba una función que reciba dos listas enlazadas y devuelva una nueva lista enlazada combinando los valores únicos
#
# de ambas.

# %%
from random import randint


class Node:
    __slots__ = 'value', 'next'

    def __init__(self, value):
        self.value = value
        self.next = None

    def __str__(self):
        return str(self.value)


class LinkedList:

    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def __iter__(self):
        curr_node = self.head
        while curr_node is not None:
            yield curr_node
            curr_node = curr_node.next

    def __str__(self):
        result = [str(x.value) for x in self]
        return '--'.join(result)

    def append(self, value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = None
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1

    def prepend(self, value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node
        self.length += 1

    def get(self, index):
        if index == -1 or index == self.length - 1:
            return self.tail
        elif index < -1 or index >= self.length:
            return None

        indextemp = 0
        for cur_nodo in self:
            if indextemp == index:
                return cur_nodo
            indextemp += 1

    def insert(self, value, index):
        if index == 0:
            self.prepend(value)
            return True
        elif index == -1 or index == self.length - 1:
            self.append(value)
            return True
        elif index < -1 or index > self.length - 1:
            return False
        else:
            new_node = Node(value)
            prev_node = self.get(index - 1)
            new_node.next = prev_node.next
            prev_node.next = new_node
            self.length += 1
            return True
        return False

    def traverse(self):
        for x in self:
            print(x.value)

    def search(self, target):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"
        else:
            for cur_nodo in self:
                if cur_nodo.value == target:
                    return True

            return False

    def set(self, target, newtarget):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"
        else:
            for cur_nodo in self:
                if cur_nodo.value == target:
                    cur_nodo.value = newtarget
                    return True
            return False

    def pop_first(self):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"

        elif self.length == 1:
            popped_node = self.head
            self.head = None
            self.tail = None
            self.length = 0
            return popped_node
        else:
            popped_node = self.head
            self.head = self.head.next
            self.length -= 1
            popped_node.next = None
            return popped_node

    def pop(self):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"

        elif self.length == 1:
            popped_node = self.head
            self.head = None
            self.tail = None
            self.length = 0
            return popped_node
        else:
            popped_node = self.tail
            print("previo cola", self.get(self.length - 2))
            self.tail = self.get(self.length - 2)
            self.tail.next = None
            self.length -= 1
            return popped_node

    def remove(self, index):
        if index == 0:
            return self.pop_first()
        elif index == -1 or index == self.length - 1:
            return self.pop()
        elif index < -1 or index > self.length - 1:
            return False
        else:
            popped_node = self.get(index)
            prev_node = self.get(index - 1)
            prev_node.next = popped_node.next
            popped_node.next = None
            self.length -= 1
            return popped_node
        return False

    def delete(self):
        self.head = None
        self.tail = None
        self.length = 0

    def generate(self, n, minvalue, maxvalue):
        self.head = None
        self.tail = None
        self.length = 0
        for _ in range(n):
            self.append(randint(minvalue, maxvalue))

def combine_unique_values(ll1, ll2):
    combined_list = LinkedList()

    def add_unique_values(node):
        current_combined = combined_list.head
        while node:
            #para verificar si el valor del nodo ya esta en la LinkedList
            verificar = True 
            while current_combined:
                if current_combined.value == node.value:
                    verificar = False
                    break
                current_combined = current_combined.next
            if verificar:
                combined_list.append(node.value)
            node = node.next
            current_combined = combined_list.head

    add_unique_values(ll1.head)
    add_unique_values(ll2.head)

    return combined_list

# Ejemplo de uso:
customll = LinkedList()
customll.append(1)
customll.append(2)
customll.append(3)

customll2 = LinkedList()
customll2.append(3)
customll2.append(4)
customll2.append(5)

combined_list = combine_unique_values(customll, customll2)
print("Lista combinada:", combined_list)
# Out:
# Lista combinada: 1--2--3--4--5

# %% [markdown]
# cuarto)
#
# Cree una función que reciba dos listas enlazadas representando números. Devuelva una lista enlazada con el resultado
#
# de la suma de estos números.
#
# Cada lista enlazada representa el número invertido.
#
# El resultado debe representar el resultado en una lista enlazada donde cada nodo representa un dígito del número.

# %%
from random import randint

#En este ejercicio tuve inconvenientes al resolverlo ya que nunca me daba la suma bien, por eso busque una guia
#Utilice este video para hacerlo y entender 
# https://www.youtube.com/watch?v=0mhiVGtcd10
class Node:
    __slots__ = 'value', 'next'

    def __init__(self, value):
        self.value = value
        self.next = None

    def __str__(self):
        return str(self.value)


class LinkedList:

    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def __iter__(self):
        curr_node = self.head
        while curr_node is not None:
            yield curr_node
            curr_node = curr_node.next

    def __str__(self):
        result = [str(x.value) for x in self]
        return '--'.join(result)

    def append(self, value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = None
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1

    def prepend(self, value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node
        self.length += 1

    def get(self, index):
        if index == -1 or index == self.length - 1:
            return self.tail
        elif index < -1 or index >= self.length:
            return None

        indextemp = 0
        for cur_nodo in self:
            if indextemp == index:
                return cur_nodo
            indextemp += 1

    def insert(self, value, index):
        if index == 0:
            self.prepend(value)
            return True
        elif index == -1 or index == self.length - 1:
            self.append(value)
            return True
        elif index < -1 or index > self.length - 1:
            return False
        else:
            new_node = Node(value)
            prev_node = self.get(index - 1)
            new_node.next = prev_node.next
            prev_node.next = new_node
            self.length += 1
            return True
        return False

    def traverse(self):
        for x in self:
            print(x.value)

    def search(self, target):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"
        else:
            for cur_nodo in self:
                if cur_nodo.value == target:
                    return True

            return False

    def set(self, target, newtarget):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"
        else:
            for cur_nodo in self:
                if cur_nodo.value == target:
                    cur_nodo.value = newtarget
                    return True
            return False

    def pop_first(self):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"

        elif self.length == 1:
            popped_node = self.head
            self.head = None
            self.tail = None
            self.length = 0
            return popped_node
        else:
            popped_node = self.head
            self.head = self.head.next
            self.length -= 1
            popped_node.next = None
            return popped_node

    def pop(self):
        if self.head == None:
            return "No hay elementos para realizar la busqueda"

        elif self.length == 1:
            popped_node = self.head
            self.head = None
            self.tail = None
            self.length = 0
            return popped_node
        else:
            popped_node = self.tail
            print("previo cola", self.get(self.length - 2))
            self.tail = self.get(self.length - 2)
            self.tail.next = None
            self.length -= 1
            return popped_node

    def remove(self, index):
        if index == 0:
            return self.pop_first()
        elif index == -1 or index == self.length - 1:
            return self.pop()
        elif index < -1 or index > self.length - 1:
            return False
        else:
            popped_node = self.get(index)
            prev_node = self.get(index - 1)
            prev_node.next = popped_node.next
            popped_node.next = None
            self.length -= 1
            return popped_node
        return False

    def delete(self):
        self.head = None
        self.tail = None
        self.length = 0

    def generate(self, n, minvalue, maxvalue):
        self.head = None
        self.tail = None
        self.length = 0
        for _ in range(n):
            self.append(randint(minvalue, maxvalue))
"""
Guia de codigo.
def addsamenode(ll1, ll2, value):
  newnode = Node(value)

  ll1.tail.next = newnode
  ll1.tail = newnode
  ll1.length +=1

  ll2.tail.next = newnode
  ll2.tail = newnode
  ll2.length +=1  
  """       

def add_linked_lists(ll1, ll2):
    #Nodo con valor para simplificar
    new_node = Node(0)  
    current = new_node
    #
    carry = 0  

    node1 = ll1.head 
    node2 = ll2.head

    while node1 or node2 or carry:
        value1 = node1.value if node1 else 0
        value2 = node2.value if node2 else 0
        
        total = value1 + value2 + carry
        carry = total // 10  
        current.next = Node(total % 10)  
        current = current.next
        
        if node1:
            node1 = node1.next
        if node2:
            node2 = node2.next

    return new_node.next 


customll = LinkedList()
customll2 = LinkedList()

customll.append(2)  # 342 -> 2 -> 4 -> 3
customll.append(4)
customll.append(3)

customll2.append(5)  # 465 -> 5 -> 6 -> 4
customll2.append(6)
customll2.append(4)

print("Lista 1:", customll)
print("Lista 2:", customll2)

#Suma de las dos listas
suma = LinkedList()
suma.head = add_linked_lists(customll, customll2)
print("Resultado de la suma:", suma)
# Out:
# Lista 1: 2--4--3
# Lista 2: 5--6--4
# Resultado de la suma: 7--0--8

# %% [markdown]
# Quinto punto)
#
# Implemente un metodo llamado reverse dentro de la clase de listas doblemente enlazadas, que reverse
#
# el orden de los nodos, ejemplo el primer nodo se convierte el ultimo, el segundo nodo se coNvierte
#
# en el penultimo y asi.
#
# Este metodo no debe recibir ningun parametro de entrada.
#
# **NOTA: No puede cambiar el valor de ninguno de los nodos, cambie la dirección de los apuntadores,
#
# UTILIZAR LA CLASE BASE DEL CURSO**

# %%
class Node:
    __slots__ = 'value', 'next', 'prev'

    def __init__(self, value):
        self.value = value
        self.next = None
        self.prev = None

    def __str__(self):
        return str(self.value)


class DoubleLinkedList:

    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def __iter__(self):
        curr_node = self.head
        while curr_node is not None:
            yield curr_node
            curr_node = curr_node.next

    def __str__(self):
        result = [str(x.prev) + '<--' + str(x.value) + '-->' + str(x.next) for x in self]
        #result = [str(x.value) for x in self]
        return '  '.join(result)

    def append(self, value):
        new_node = Node(value)
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
        self.length += 1

    def prepend(self, value):
        new_node = Node(value)
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head.prev = new_node
            self.head = new_node
        self.length += 1

    def get(self, index):
        if index == -1 or index == self.length - 1:
            return self.tail
        elif index < -1 or index >= self.length:
            return None

        indextemp = 0
        for cur_nodo in self:
            if indextemp == index:
                return cur_nodo
            indextemp += 1

    def insert(self, value, index):
        if index == 0:
            self.prepend(value)
            return True
        elif index == -1 or index == self.length - 1:
            self.append(value)
            return True
        elif index < -1 or index > self.length - 1:
            return False
        else:
            new_node = Node(value)
            prev_node = self.get(index - 1)
            nextnode = self.get(index)
            new_node.next = prev_node.next
            new_node.prev = prev_node
            prev_node.next = new_node
            nextnode.prev = new_node
            self.length += 1
            return True

        return False

    def traverse(self):
        for cur_node in self:
            print(cur_node.value)

    def search(self, target):
        index = 0
        for cur_node in self:
            if cur_node.value == target:
                return index
            index += 1
        return -1

    def set(self, index, value):
        temp = self.get(index)
        if temp:
            temp.value = value
            return True
        return False

    def pop_first(self):
        if self.length == 0:
            return None
        popped_node = self.head
        if self.length == 1:
            self.head = self.tail = None
        else:
            self.head = self.head.next
            self.head.prev = None
            popped_node.next = None
        self.length -= 1
        return popped_node

    def pop(self):
        if self.length == 0:
            return None
        popped_node = self.tail
        if self.length == 1:
            self.head = self.tail = None
        else:
            prevtail_node = self.get(self.length - 2)
            prevtail_node.next = None
            self.tail = prevtail_node
        self.length -= 1
        return popped_node

    def remove(self, index):
        if index < -1 and index >= self.length:
            return None
        if index == 0:
            return self.pop_first()
        if index == -1 or index == self.length - 1:
            return self.pop()
        prev_node = self.get(index - 1)
        next_node = self.get(index)
        popped_node = prev_node.next
        prev_node.next = popped_node.next
        next_node.prev = prev_node
        popped_node.next = None
        self.length -= 1
        return popped_node

    def delete_all(self):
        self.head = None
        self.tail = None
        self.length = 0

    def generate(self, n, minvalue, maxvalue):

        self.head = None
        self.tail = None
        self.length = 0
        for i in range(n):
            self.append(randint(minvalue, maxvalue))
        return self
    """
    Guia de ejercicio tomado en clase
    def reversedLL(head):
    
      currnode = head
      prevnode = None
    
      while currnode:
        nextnode = currnode.next
        currnode.next = prevnode
    
        prevnode = currnode
        currnode = nextnode
    
      return prevnode
    """
    def reverse(self):
        current = self.head
        prev_node = None
        while current:
            next_node = current.next
            current.next = prev_node
            prev_node = current
            current.prev = next_node
            current = next_node
        self.head = prev_node
        return self



customDlinkedlist = DoubleLinkedList()
customDlinkedlist.append(1)
customDlinkedlist.append(2)
customDlinkedlist.append(3)
customDlinkedlist.append(4)

print("Lista original:")
print(customDlinkedlist)

#Invertimos la lista
customDlinkedlist.reverse()

print("Lista invertida:")
print(customDlinkedlist)
# Out:
# Lista original:
# None<--1-->2  1<--2-->3  2<--3-->4  3<--4-->None
# Lista invertida:
# None<--4-->3  4<--3-->2  3<--2-->1  2<--1-->None
